# %% [markdown]
# <a href="https://colab.research.google.com/github/sezinbiner/Covid_X_ray_Classification/blob/main/split_folders.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID")[:2400]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/train/covid"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/Normal") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/Normal")[:2400]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/train/normal"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass
# Out:
# Normal-9113.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9113.png
# Normal-9094.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9094.png
# Normal-9082.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9082.png
# Normal-9105.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9105.png
# Normal-9093.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9093.png
# Normal-911.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-911.png
# Normal-9089.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9089.png
# Normal-9096.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9096.png
# Normal-9102.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9102.png
# Normal-9112.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9112.png
# Normal-9090.png
# /content/gdrive/MyDrive/bitirme dataset 2/train/normal/Normal-9090.png
# ...

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID")[2400:3000]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/validation/covid"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass
# Out:
# COVID-1915.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1915.png
# COVID-1913.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1913.png
# COVID-1914.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1914.png
# COVID-1911.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1911.png
# COVID-1917.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1917.png
# COVID-1918.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1918.png
# COVID-1919.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1919.png
# COVID-1920.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1920.png
# COVID-192.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-192.png
# COVID-1922.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/covid/COVID-1922.png
# COVID-1921.png
# ...

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/Normal")[2400:3000]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/validation/normal"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass
# Out:
# Normal-7664.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7664.png
# Normal-7659.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7659.png
# Normal-7662.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7662.png
# Normal-7670.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7670.png
# Normal-7663.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7663.png
# Normal-7666.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7666.png
# Normal-767.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-767.png
# Normal-7660.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7660.png
# Normal-7665.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7665.png
# Normal-7669.png
# /content/gdrive/MyDrive/bitirme dataset 2/validation/normal/Normal-7669.png
# Normal-7656.png
# ...

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID")[3000:3616]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/test/test"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass
# Out:
# /content/gdrive/MyDrive/bitirme dataset/test/test1/1
# /content/gdrive/MyDrive/bitirme dataset/test/test1/2
# /content/gdrive/MyDrive/bitirme dataset/test/test1/3
# /content/gdrive/MyDrive/bitirme dataset/test/test1/4
# /content/gdrive/MyDrive/bitirme dataset/test/test1/5
# /content/gdrive/MyDrive/bitirme dataset/test/test1/6
# /content/gdrive/MyDrive/bitirme dataset/test/test1/7
# /content/gdrive/MyDrive/bitirme dataset/test/test1/8
# /content/gdrive/MyDrive/bitirme dataset/test/test1/9
# /content/gdrive/MyDrive/bitirme dataset/test/test1/10
# /content/gdrive/MyDrive/bitirme dataset/test/test1/11
# /content/gdrive/MyDrive/bitirme dataset/test/test1/12
# /content/gdrive/MyDrive/bitirme dataset/test/test1/13
# /content/gdrive/MyDrive/bitirme dataset/test/test1/14
# /content/gdrive/MyDrive/bitirme dataset/test/test1/15
# /content/gdrive/MyDrive/bitirme dataset/test/test1/16
# /content/gdrive/MyDrive/bitirme dataset/test/test1/17
# /content/gdrive/MyDrive/bitirme dataset/test/test1/18
# ...

# %%
import os
import cv2
os.chdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/COVID") 
for im in os.listdir("/content/gdrive/MyDrive/Kaggle/COVID-19_Radiography_Dataset/Normal")[3000:3616]:
  print(im)
  try:
      img = cv2.imread(im,cv2.IMREAD_COLOR)
      path = "/content/gdrive/MyDrive/bitirme dataset/test/test"
      print(os.path.join(path,im))
      cv2.imwrite(os.path.join(path,im), img)
  except Exception as e:
      pass
# Out:
# Normal-6393.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6393.png
# Normal-6397.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6397.png
# Normal-639.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-639.png
# Normal-6412.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6412.png
# Normal-640.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-640.png
# Normal-6406.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6406.png
# Normal-6403.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6403.png
# Normal-6392.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6392.png
# Normal-6396.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6396.png
# Normal-6390.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6390.png
# Normal-6395.png
# /content/gdrive/MyDrive/bitirme dataset/test/normal/Normal-6395.png
# Normal-6402.png
# ...
