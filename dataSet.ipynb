# %% [markdown]
# <a href="https://colab.research.google.com/github/sezinbiner/Covid_X_ray_Classification/blob/main/dataSet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"

# %%
# %cd /content/gdrive/My Drive/Kaggle
# Out:
# /content/gdrive/My Drive/Kaggle

# %%
# !kaggle datasets download -d tawsifurrahman/covid19-radiography-database
# Out:
# ...
#  99% 739M/745M [00:07<00:00, 102MB/s]
# 100% 745M/745M [00:07<00:00, 98.8MB/s]

# %%
# !ls
# Out:
# covid19-radiography-database.zip  kaggle.json

# %%
# !unzip \*.zip  && rm *.zip
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-563.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5630.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5631.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5632.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5633.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5634.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5635.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5636.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5637.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5638.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5639.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-564.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5640.png
#   inflating: COVID-19_Radiography_Dataset/Normal/Normal-5641.png
# ...
